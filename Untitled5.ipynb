# %% [markdown]
# <a href="https://colab.research.google.com/github/mujehoxe/ahkam_dataset/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline

pipe = pipeline("automatic-speech-recognition", model="tarteel-ai/whisper-base-ar-quran")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
audio_file_path = "drive/MyDrive/0.wav"

transcription = pipe(audio_file_path)

print("Transcription:", transcription)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-b2dae681e762> in <cell line: 3>()
#       1 audio_file_path = "drive/MyDrive/0.wav"
#       2
# ----> 3 transcription = pipe(audio_file_path)
#       4
#       5 print("Transcription:", transcription)
#
# NameError: name 'pipe' is not defined

# %%
# !pip install librosa

# %%
import librosa

mp3_file_path = "drive/MyDrive/001001.mp3"

# Load MP3 file using librosa
audio, _ = librosa.load(mp3_file_path, sr=16000)  # Adjust the sample rate if needed

transcription = pipe(audio)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-821f017e250e> in <cell line: 8>()
#       6 audio, _ = librosa.load(mp3_file_path, sr=16000)  # Adjust the sample rate if needed
#       7
# ----> 8 transcription = pipe(audio)
#
# NameError: name 'pipe' is not defined

# %%
print("Transcription:", transcription)

# %%
# !pip install -U openai-whisper

# %%
import whisper

model = whisper.load_model("base")

# %%
# !pip install datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 6.9 MB/s eta 0:00:00
# ...

# %%
import torch
from transformers import AutoProcessor, WhisperForConditionalGeneration
from datasets import load_dataset

processor = AutoProcessor.from_pretrained("openai/whisper-tiny.en")
model = WhisperForConditionalGeneration.from_pretrained("openai/whisper-tiny.en")

ds = load_dataset("hf-internal-testing/librispeech_asr_dummy", "clean", split="validation")

inputs = processor(ds[0]["audio"]["array"], return_tensors="pt")
input_features = inputs.input_features

generated_ids = model.generate(inputs=input_features,return_timestamps=True )

transcription = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
transcription
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/185k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/805 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.41M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/34.6k [00:00<?, ?B/s]
# ...

# %%
print(generated_ids)

# %%
print(ds[0])

# %%
# !pip3 install whisper-timestamped

# %%
import whisper_timestamped as whisper

audio = whisper.load_audio("drive/MyDrive/001007.wav")

model = whisper.load_model("tarteel-ai/whisper-base-ar-quran", device="cpu")

result = whisper.transcribe(model, audio, language="ar")

import json
print(json.dumps(result, indent = 2, ensure_ascii = False))

# %%
# !pip install -U stable-ts

# %%
import stable_whisper
#model = whisper.load_model("tarteel-ai/whisper-base-ar-quran", device="cpu")
model = stable_whisper.load_model('pytorch_model.bin')
result = model.transcribe("drive/MyDrive/001007.wav", language='ar')
result.to_srt_vtt('audio.srt' ,segment_level=False)

# %%
print(result.all_words)
# Out:
# <bound method WhisperResult.all_words of <stable_whisper.result.WhisperResult object at 0x78134cbd2a40>>

# %%
# !pip install faster-whisper

# %%
model = stable_whisper.load_faster_whisper('base')
result = model.transcribe_stable('drive/MyDrive/001007.wav')
result.save_as_json('audio.json')

# %%
text = "صِرَاطَ الَّذِينَ أَنْعَمْتَ عَلَيْهِمْ غَيْرِ الْمَغْضُوبِ عَلَيْهِمْ وَلَا الضَّالِّينَ"

result = model.align('drive/MyDrive/001007.wav', text, language='en')
result.save_as_json('audio.json')
# Out:
# Align: 100%|██████████| 20.22/20.22 [00:13<00:00,  1.45sec/s]
# Saved: /content/audio.json

# %%
# !sudo apt-get install sox
# !pip install sox
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# sox is already the newest version (14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 30 not upgraded.
# ...

# %%
# !sudo apt install libsox-dev

# %%
import pandas as pd
import os

# %%
# !ssh-keygen -t ed25519 -C "your_email@example.com"
# !ssh-add ~/.ssh/id_ed25519

# %%
! cat ~/.ssh/id_ed25519.pub
# Out:
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAIMXwv2xf/S6H1+/e1+TeffpYff+/6UNcNIqaD2CtuLX/ your_email@example.com

# %%
results = [
    {'file_name': 'file1.wav', 'text': 'text1', 'example': 'example1'},
    {'file_name': 'file2.wav', 'text': 'text2', 'example': 'example2'},
]

df = pd.DataFrame(results)
csv_file_path = "/content/data.csv"
df.to_csv(csv_file_path, index=False)

# %%
# !mkdir ahkam_dataset
# !cp /content/data.csv /content/ahkam_dataset/
# !cp /content/drive/MyDrive/*.wav /content/ahkam_dataset/
os.chdir("/content/ahkam_dataset/")
# !echo "# ahkam_dataset" >> README.md
# !git init
# !git config --global init.defaultBranch
# !git add .
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://github.com/mujehoxe/ahkam_dataset.git
# !git push -u origin main
os.chdir("/content")
# Out:
# mkdir: cannot create directory ‘ahkam_dataset’: File exists
# Reinitialized existing Git repository in /content/ahkam_dataset/.git/
# [main 50c5471] first commit
#  4 files changed, 4 insertions(+)
#  create mode 100644 0.wav
#  create mode 100644 001007.wav
#  create mode 100644 data.csv
# error: remote origin already exists.
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
os.chdir("/content")

# %%
# !rm -r ahkam_dataset/
